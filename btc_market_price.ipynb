# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C://Users//aishw//OneDrive//Desktop//bitcoin_dataset.csv')

# %%
df.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
df.iloc[1023]['btc_market_price']
# Out:
# 13.6888

# %%
df.corr()
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.392474
# btc_market_cap                                              0.999783
# btc_trade_volume                                            0.868813
# btc_blocks_size                                             0.674507
# btc_avg_block_size                                          0.544033
# btc_n_orphaned_blocks                                      -0.076400
# btc_n_transactions_per_block                                0.544125
# btc_median_confirmation_time                                0.275250
# btc_hash_rate                                               0.920876
# btc_difficulty                                              0.916937
# btc_miners_revenue                                          0.986732
# btc_transaction_fees                                        0.806595
# ...

# %%
df.shape
# Out:
# (2906, 24)

# %%
sns.jointplot(x = "btc_market_cap", y = "btc_market_price", 
              kind = "scatter", data = df)
plt.show()

# %%
from scipy import stats

# %%
x1 = df['btc_market_cap']
y1 = df['btc_market_price']
stats.pearsonr(x1,y1)
# Out:
# (0.9997826765218778, 0.0)

# %%
df.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                     27
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                        29
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                           12
# btc_hash_rate                                           0
# btc_difficulty                                         16
# btc_miners_revenue                                      0
# btc_transaction_fees                                   10
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# ...

# %%
df1=df.fillna(0)

# %%
df1.isnull().sum()
# Out:
# Date                                                   0
# btc_market_price                                       0
# btc_total_bitcoins                                     0
# btc_market_cap                                         0
# btc_trade_volume                                       0
# btc_blocks_size                                        0
# btc_avg_block_size                                     0
# btc_n_orphaned_blocks                                  0
# btc_n_transactions_per_block                           0
# btc_median_confirmation_time                           0
# btc_hash_rate                                          0
# btc_difficulty                                         0
# btc_miners_revenue                                     0
# btc_transaction_fees                                   0
# btc_cost_per_transaction_percent                       0
# btc_cost_per_transaction                               0
# ...

# %%
df1.corr()
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.388153
# btc_market_cap                                              0.999783
# btc_trade_volume                                            0.868837
# btc_blocks_size                                             0.674795
# btc_avg_block_size                                          0.544033
# btc_n_orphaned_blocks                                      -0.076400
# btc_n_transactions_per_block                                0.544125
# btc_median_confirmation_time                                0.263938
# btc_hash_rate                                               0.920876
# btc_difficulty                                              0.916228
# btc_miners_revenue                                          0.986732
# btc_transaction_fees                                        0.806329
# ...

# %%
x=df1[["btc_total_bitcoins",'btc_market_cap','btc_blocks_size','btc_cost_per_transaction',"btc_n_transactions_per_block"]]
y=df1[["btc_market_price"]]

# %%
pip install sklearn

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.9999078442311431

# %%
model_df1=model.fit(x_train,y_train)

# %%
df1=model_df1.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, df1)
# Out:
# 506.58305201577235
